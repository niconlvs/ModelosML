# %%
import pandas as pd

# %% [markdown]
# ##Revisión de Datos

# %%
ruta="C:/Users/user/Downloads/ML/sabana.json"
df = pd.read_json(ruta, orient='records')
df.head()
# Out:
#    N                                           PROYECTO CLIENTE BUENO / MALO  \
# 0  1                                      CASA DE CAMPO                BUENO
# 1  3                  OBRA CIVIL PLANTA RIVAL GUAYAQUIL                BUENO
# 2  4  REDES DE DISTRIBUCION SISTEMA YANUNCAY SEGUNDA...                BUENO
# 3  5                            TORRES MEDICAS 1, 2 Y 3                BUENO
# 4  6                    ANCLAJES Y MUROS TORRE MEDICA 1                BUENO
#
#                                             Contrato  \
# 0  1. CONTRATO DE CONSTRUCCIÓN PRIMERA ETAPA CAS...
# 1  3. CONTRATO DE CONSTRUCIÓN NAVE INDUSTRIAL PL...
# 2  4. CONTRATO DE CONSTRUCCIÓN PROYECTO YANUNCAY...
# 3                            5. CONTRATO TORRE 1.pdf
# 4  6. CONTRATO PARA ANCLAJES DE MUROS DE CONTENCI...
#
#                                            Direccion  \
# 0  /Volumes/Expansion/Trabajo/Trabajo/Prex/Client...
# 1  /Volumes/Expansion/Trabajo/Trabajo/Prex/Client...
# ...

# %%
df.columns
# Out:
# Index(['N', 'PROYECTO', 'CLIENTE BUENO / MALO', 'Contrato', 'Direccion',
#        'Nombre txt', 'Direccion txt crudo', 'Direccion txt limpio',
#        'sentimiento_polaridad', 'tono_legal', 'riesgo_puntaje', 'contratación',
#        'acero', 'provisional', 'garantía', 'definitiva', 'plano', 'nacional',
#        'objeto', 'civil', 'anticipo', 'mediante', 'precios', 'suministro',
#        'tubería', 'dentro', 'control', 'fase', 'ingenieros', 'instalaciones',
#        'conforme', 'anexo', 'actividades', 'oficinas', 'fiscalizador'],
#       dtype='object')

# %%
#Eliminar las columnas N, PROYECTO, CONTRATO, DIRECCION, NOMBRE, DIRECCION TXT CRUDO, DIRECCION TXT LIMPIO
